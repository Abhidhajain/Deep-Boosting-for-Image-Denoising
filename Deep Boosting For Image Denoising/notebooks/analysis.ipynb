# %% [markdown]
# #PLOTTING GRAPH

# %%
import pickle
layer_1 = pickle.load(open('1_layer_history', 'rb'))
layer_2 = pickle.load(open('2_layer_history', 'rb'))
layer_3 = pickle.load(open('3_layer_history', 'rb'))
layer_4 = pickle.load(open('4_layer_history', 'rb'))
layer_5 = pickle.load(open('5_layer_history', 'rb'))

# %%
print(layer_1)
# Out:
# {'loss': [0.0408075675368309, 0.007905167527496815, 0.0046168128028512, 0.004076207987964153, 0.0034326394088566303, 0.0031359123531728983, 0.003287927946075797, 0.0028341251891106367, 0.002535554114729166, 0.002393157687038183, 0.002339401748031378, 0.0022838227450847626, 0.0022067406680434942, 0.002126541221514344, 0.0021850767079740763, 0.0020649656653404236, 0.0020047298166900873, 0.001939538517035544, 0.0019418856827542186, 0.0018823558930307627, 0.0018501251470297575, 0.0018212230643257499, 0.0018596366280689836, 0.0017664659535512328, 0.001746860332787037, 0.0017454084008932114, 0.0020796963945031166, 0.0017649497603997588, 0.001701459288597107, 0.0016787907807156444, 0.0017077826196327806, 0.0016455240547657013, 0.001637590117752552, 0.0016403156332671642, 0.0016200930112972856, 0.001595832989551127, 0.0016652119811624289, 0.0015960640739649534, 0.001582795986905694, 0.0016243314603343606, 0.0015862801810726523, 0.001556606381200254, 0.0015443273587152362, 0.00163580127991735
# ...

# %%
# print(layer_2.history["val_loss"])
import numpy as np
import matplotlib.pyplot as plt
Y1 = np.array(layer_1['loss'])
Y2 = np.array(layer_2['loss'])
Y3 = np.array(layer_3['loss'])
Y4 = np.array(layer_4['loss'])
Y5 = np.array(layer_5['loss'])

plt.plot(Y1, color='yellow', label='DDFN1', linewidth=4)
plt.plot(Y2, color='r', label='DDFN2', linewidth=2)
plt.plot(Y3, color='b', label='DDFN3', linewidth=2)
plt.plot(Y4, color='g', label='DDFN4', linewidth=2)
plt.plot(Y5, color='black', label='DDFN5', linewidth=2)


plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("{} vs Epoch".format("loss"))

plt.legend()
plt.show()

# %%
import pickle
layer_1 = pickle.load(open('pn_layer_1_history', 'rb'))
layer_2 = pickle.load(open('pn_layer_2_history', 'rb'))
layer_3 = pickle.load(open('pn_layer_3_history', 'rb'))
layer_4 = pickle.load(open('pn_layer_4_history', 'rb'))
layer_5 = pickle.load(open('pn_layer_5_history', 'rb'))

# %%
import numpy as np
import matplotlib.pyplot as plt
Y1 = np.array(layer_1['loss'])
Y2 = np.array(layer_2['loss'])
Y3 = np.array(layer_3['loss'])
Y4 = np.array(layer_4['loss'])
Y5 = np.array(layer_5['loss'])

plt.plot(Y1, color='yellow', label='PN1', linewidth=4)
plt.plot(Y2, color='r', label='PN2', linewidth=2)
plt.plot(Y3, color='b', label='PN3', linewidth=2)
plt.plot(Y4, color='g', label='PN4', linewidth=2)
plt.plot(Y5, color='black', label='PN5', linewidth=2)


plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("{} vs Epoch".format("loss"))

plt.legend()
plt.show()

# %%
import pickle
layer_1 = pickle.load(open('ddn_layer_1_history', 'rb'))
layer_2 = pickle.load(open('ddn_layer_2_history', 'rb'))
layer_3 = pickle.load(open('ddn_layer_3_history', 'rb'))
layer_4 = pickle.load(open('ddn_layer_4_history', 'rb'))
layer_5 = pickle.load(open('ddn_layer_5_history', 'rb'))

# %%
Y1 = np.array(layer_1['loss'])
Y2 = np.array(layer_2['loss'])
Y3 = np.array(layer_3['loss'])
Y4 = np.array(layer_4['loss'])
Y5 = np.array(layer_5['loss'])

plt.plot(Y1, color='yellow', label='DDN1', linewidth=2)
plt.plot(Y2, color='r', label='DDN2', linewidth=2)
plt.plot(Y3, color='b', label='DDN3', linewidth=2)
plt.plot(Y4, color='g', label='DDN4', linewidth=2)
plt.plot(Y5, color='black', label='DDN5', linewidth=2)


plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("{} vs Epoch".format("loss"))

plt.legend()
plt.show()

# %% [markdown]
# PSNR

# %%
PSNR_PN = [59.5586539371983, 59.9923732832321, 60.258417426258944, 62.30621701477675,62.23710547448981]
PSNR_DDFN = [58.273306384785116, 58.558653936325824, 59.258417426258944, 59.44526150825719, 60.740528845663405]

plt.plot(PSNR_DDFN, marker='^'  ,color='r', label = 'DDFN')
plt.plot(PSNR_PN,  marker='o', color='b', label = 'PN')
plt.ylabel("PSNR")
plt.xlabel("layers")
plt.title("PSNR vs layers".format("loss"))

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
PSNR_PN = [59.6646539231829, 60.012374832357, 60.748417322258954,61.89246120878488,62.3338766126613]
PSNR_DDFN = [58.273306384785116, 58.558653936325824, 59.258417426258944, 59.44526150825719, 60.740528845663405]

plt.plot(PSNR_DDFN, marker='^'  ,color='r', label = 'DDFN')
plt.plot(PSNR_PN,  marker='o', color='b', label = 'DDN')
plt.ylabel("PSNR")
plt.xlabel("layers")
plt.title("PSNR vs layers".format("loss"))

plt.legend()
plt.show()
